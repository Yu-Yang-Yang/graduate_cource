# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy import optimize
import seaborn as sns
sns.set(style="whitegrid")
a = np.random.rand(10);

# %%
a
# Out:
# array([0.18194546, 0.27085283, 0.21532002, 0.9409707 , 0.89976731,
#        0.58939704, 0.07404595, 0.93791996, 0.31293037, 0.00884467])

# %%
value,bins = np.histogram(a)

# %%
plt.plot(bins[:-1],value)

# %%
x = np.array([3.5, 1.1, 3.2, 2.8, 6.7, 4.4, 0.9, 2.2])
np.mean(x)
# Out:
# 3.1

# %%
np.median(x)
# Out:
# 3.0

# %%
np.random.rand()
# Out:
# 0.285647685693605

# %%
np.random.randn()
# Out:
# 0.9699344190919796

# %%
np.random.rand(5)
# Out:
# array([0.02031022, 0.15053532, 0.52608618, 0.9226499 , 0.41249088])

# %%
np.random.randn(2, 4)
# Out:
# array([[-0.87858712,  0.08889125, -0.6572329 ,  0.62109404],
#        [ 0.94034267, -0.11793008, -0.42366271, -1.48629333]])

# %%
np.random.randint(10, size=10)
# Out:
# array([7, 0, 0, 3, 9, 3, 0, 0, 2, 3])

# %%
np.random.randint(low=10, high=20, size=(2, 10))
# Out:
# array([[11, 16, 15, 12, 13, 17, 17, 10, 14, 10],
#        [13, 13, 12, 19, 18, 14, 11, 16, 19, 15]])

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 3))
axes[0].hist(np.random.rand(10000))
axes[0].set_title("rand")
axes[1].hist(np.random.randn(10000))
axes[1].set_title("randn")
axes[2].hist(np.random.randint(low=1, high=10, size=10000),
bins=9, align='left')
axes[2].set_title("randint(low=1, high=10)")
# Out:
# Text(0.5, 1.0, 'randint(low=1, high=10)')
